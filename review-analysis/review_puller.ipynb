# %%
import os
import sys

# %%
cwd = !pwd
sys.path.append(os.path.split(cwd[0])[0])

# %%
from fantastic_amazon import amazon_scraper, sheets_connector

# %%
SERVICE_FILE = "/home/max/fantastic-amazon-c1ba8f85a23b.json"
SHEET_KEY = "1M8FT1qtKr5VgUAk-7IvQdX8Hp2Sn13uZLL3tq2o7YOU"
SHEET_NAME = "PRICES"

# %%
gs = sheets_connector.GoogleSheets(sheet_key=SHEET_KEY, sheet_name=SHEET_NAME, service_file=SERVICE_FILE)

# %%
PNs = gs.w.range("B3:B30")

# %%
url_dict = {} 
for PN in PNs:
    url_row = 'H' + str(PN[0].row) + ':J' + str(PN[0].row) 
    urls = gs.get_urls(url_row)
    url_dict[PN[0].value] = urls

# %%
# scraper.scrape('amazon.com', url=list(url_dict.items())[0][1][0])

# %%
import threading

class ThreadSafeDict(dict) :
    def __init__(self, * p_arg, ** n_arg) :
        dict.__init__(self, * p_arg, ** n_arg)
        self._lock = threading.Lock()

    def __enter__(self) :
        self._lock.acquire()
        return self

    def __exit__(self, type, value, traceback) :
        self._lock.release()

# %%
def scraper_t(PN, url):
    if url:
        try:
            scrape_result = amazon_scraper.AmazonScrapper().scrape('amazon.com', url=url, headless=True)
            review_master_dict[PN][url] = scrape_result
        except Exception as e:
            print(e)

# %%
from threading import Thread
import time
from concurrent.futures import ThreadPoolExecutor

#chunking the list
n = 10
lst = list(url_dict.items())
review_master_dict = {PN: {url: {} for url in urls} for PN, urls in lst}
lst_flat = [(pn, _url) for pn, urls in lst for _url in urls ]
# iter_list = [lst[i:i + n] for i in range(0, len(lst), n)]
ts = []
for PN, url in lst_flat:
    while True:
        if not ts or len(ts) < n:
            break
        else:
            scripts_finished = [not t.is_alive() for t in ts]
            if any(scripts_finished):
                pop_i = [i for i, status in enumerate(scripts_finished) if status]
                ts.pop(pop_i[0])
                break
            else:
                time.sleep(1) 
    t = Thread(target=scraper_t, args=(PN, url))
    t.start()
    ts.append(t)
    print(PN, url) #, ts)
# Out:
# C31DUAL4KDP https://www.amazon.com/StarTech-com-2-Port-USB-C-DisplayPort-MST/dp/B01KIMP28Y/ref=sr_1_5?dchild=1&keywords=USB-C+to+Dual+DisplayPort+Video+Adapter&qid=1621983565&sr=8-5
# C31DUAL4KDP https://www.amazon.com/2-Port-DisplayPort-Adapter-Monitor-Splitter/dp/B07563JV7H/ref=sr_1_8?dchild=1&keywords=USB-C+to+Dual+DisplayPort+Video+Adapter&qid=1621983565&sr=8-8
# C31DUAL4KDP https://www.amazon.com/gofanco-DisplayPort-Displayport-Thunderbolt-Compatible/dp/B07MF4QXFX/ref=sr_1_3?dchild=1&keywords=USB-C+to+Dual+DisplayPort+Video+Adapter&qid=1621983565&sr=8-3
# C31DUAL4KHDMI https://www.amazon.com/StarTech-com-2-Port-USB-C-HDMI-MST/dp/B06XPVGQKY/ref=sr_1_6?dchild=1&keywords=USB-C+to+Dual+hdmi+Video+Adapter&qid=1621983776&sr=8-6
# C31DUAL4KHDMI https://www.amazon.com/Anker-Portable-Supports-Compatible-Thunderbolt/dp/B0894B525X/ref=sr_1_9?dchild=1&keywords=USB-C+to+Dual+hdmi+Video+Adapter&qid=1621983776&sr=8-9
# C31DUAL4KHDMI https://www.amazon.com/Sabrent-Adapter-Supports-Monitors-Compatible/dp/B07H11ZHPW/ref=sr_1_20?dchild=1&keywords=USB-C+to+Dual+hdmi+Video+Adapter&qid=1621983776&sr=8-20
# C31DUALDPDOCKPD https://www.amazon.com/Docking-Station-Monitor-MacBook-Ethernet/dp/B088D5436G/ref=sr_1_102?dchild=1&keywords=usb-c+docking+station+2x+4k&qid=1621984401&s=electronics&sr=1-102
# C31DUALDPDOCKPD https://www.amazon.com/VAVA-Docking-Station-Ethernet-Charging/dp/B086DS5Q6K/ref=sr_1_34?dchild=1&keywords=usb-c+docking+station+2x+4k&qid=1621984107&s=electronics&sr=1-34
# C31DUALDPDOCKPD https://www.amazon.com/StarTech-com-Monitor-Multiport-Adapter-DisplayPort/dp/B07JZHVKFJ/ref=sr_1_6?dchild=1&keywords=USB-C+Docking+Station+2x4K+with+65W+Power+Delivery&qid=1620438249&sr=8-6
# C31DUALDPDOCKPD100WUS
# C31DUALDPDOCKPD100WUS
# C31DUALDPDOCKPD100WUS
# C31DUALDPDOCKPD65WUS
# C31DUALDPDOCKPD65WUS
# C31DUALDPDOCKPD65WUS
# C31FLATDOCKPDPRO https://www.amazon.com/MagBac-Aluminum-DisplayPort-Ethernet-External/dp/B07ZYSRTGX/ref=sr_1_13?dchild=1&keywords=USB-C+Docking+Station+4K+3+Monitors+%28HDMI%2C+VGA%2C+DisplayPort%29+Power+Delivery&qid=1621985924&s=electronics&sr=1-13
# scraping: https://www.amazon.com/dp/product-reviews/B07JZHVKFJ?pageNumber=1scraping: https://www.amazon.com/dp/product-reviews/B01KIMP28Y?pageNumber=1scraping: https://www.amazon.com/dp/product-reviews/B07ZYSRTGX?pageNumber=1
#
#
# scraping: https://www.amazon.com/dp/product-reviews/B086DS5Q6K?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B07H11ZHPW?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B06XPVGQKY?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B07563JV7H?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B07MF4QXFX?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B088D5436G?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B0894B525X?pageNumber=1
# Total reviews (all pages): 64
# Total reviews (all pages): 39
# Total reviews (all pages): 100
# Total reviews (all pages): 545
# Total reviews (all pages): 113
# Total reviews (all pages): 468
# Total reviews (all pages): 0
# Total reviews (all pages): 37
# Total reviews (all pages): 64
# Total reviews (all pages): 23
# C31FLATDOCKPDPRO
# C31FLATDOCKPDPRO
# C31FLATPRO112WUS
# C31FLATPRO112WUS
# C31FLATPRO112WUS
# C31NANODOCKLANPD https://www.amazon.com/UtechSmart-Ethernet-Delivery-Compatible-Chromebook/dp/B07H2ZS1B5/ref=sr_1_3?dchild=1&keywords=USB-C+hdmi+lan+adapter&qid=1621986229&s=electronics&sr=1-3
# scraping: https://www.amazon.com/dp/product-reviews/B07H2ZS1B5?pageNumber=1
# C31NANODOCKLANPD https://www.amazon.com/USB-Hub-Adapter-Ethernet-Charging/dp/B07QQ11BP6/ref=sr_1_10?dchild=1&keywords=USB-C+hdmi+lan+adapter&qid=1621986229&s=electronics&sr=1-10
# scraping: https://www.amazon.com/dp/product-reviews/B07QQ11BP6?pageNumber=1
# Total reviews (all pages): 1401
# C31NANODOCKLANPD
# C31NANODOCKPD https://www.amazon.com/QGeeM-Delivery-Compatible-Thunderbolt-Chromebook/dp/B07QXMNF1X/ref=sr_1_4?dchild=1&keywords=USB-C+hdmi+usb+adapter&qid=1621986375&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B07QXMNF1X?pageNumber=1
# C31NANODOCKPD https://www.amazon.com/MOKiN-MicroSD-3-Ports-Pass-Through-Adapter/dp/B078HZGWYX/ref=sr_1_71?dchild=1&keywords=USB-C+hdmi+usb+adapter&qid=1621986455&s=electronics&sr=1-71
# scraping: https://www.amazon.com/dp/product-reviews/B078HZGWYX?pageNumber=1
# Total reviews (all pages): 1588
# Total reviews (all pages): 5306
# C31NANODOCKPD
# C31NANODOCKPROPD https://www.amazon.com/Tiergrade-Display-Adapter-DisplayPort-Ethernet/dp/B07X1J7R34/ref=sr_1_19?dchild=1&keywords=USB-C+MST+usb+adapter+mst&qid=1621986599&s=electronics&sr=1-19
# scraping: https://www.amazon.com/dp/product-reviews/B07X1J7R34?pageNumber=1
# Total reviews (all pages): 410
# C31NANODOCKPROPD https://www.amazon.com/Displayport-Ethernet-Multiport-Different-Displays/dp/B082KMKQQX/ref=sr_1_21?dchild=1&keywords=USB-C+MST+usb+adapter+mst&qid=1621986599&s=electronics&sr=1-21
# scraping: https://www.amazon.com/dp/product-reviews/B082KMKQQX?pageNumber=1
# Total reviews (all pages): 573
# C31NANODOCKPROPD
# C31NANODOCKVGAPD https://www.amazon.com/Ethernet-1000Mbps-Charging-Thunderbolt-Chromebook/dp/B08H85QF1G/ref=sr_1_5?dchild=1&keywords=USB-C+Docking+Station+hdmi+vga&qid=1621986124&s=electronics&sr=1-5
# scraping: https://www.amazon.com/dp/product-reviews/B08H85QF1G?pageNumber=1
# Total reviews (all pages): 813
# C31NANODOCKVGAPD
# C31NANODOCKVGAPD
# C31QUATTRODOCKPDUS https://www.amazon.com/QGeeM-Quadruple-Charging-Specific-Thunderbolt/dp/B08G4X23DZ/ref=sr_1_6?dchild=1&keywords=docking+station+quad+display&qid=1621987240&s=electronics&sr=1-6
# scraping: https://www.amazon.com/dp/product-reviews/B08G4X23DZ?pageNumber=1
# Total reviews (all pages): 488
# Total reviews (all pages): 172
# C31QUATTRODOCKPDUS https://www.amazon.com/Targus-Universal-Docking-Station-DOCK520USZ/dp/B07KQWZTV9/ref=sr_1_4?dchild=1&keywords=docking+station+quad+display&qid=1621987240&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B07KQWZTV9?pageNumber=1
# Total reviews (all pages): 252
# C31QUATTRODOCKPDUS
# C31TRIPLEDOCKPDUS https://www.amazon.com/Plugable-Charging-Thunderbolt-Compatible-Specific/dp/B08DDH5CPW/ref=sr_1_18?dchild=1&keywords=docking+station+3+display+displayport+hdmi&qid=1621987426&s=electronics&sr=1-18
# scraping: https://www.amazon.com/dp/product-reviews/B08DDH5CPW?pageNumber=1
# C31TRIPLEDOCKPDUS https://www.amazon.com/WAVLINK-Display-Docking-Delivery-Ethernet/dp/B08FX1YJDS/ref=sr_1_5?dchild=1&keywords=wavlink+USB-C+triple+mst&qid=1621987577&s=electronics&sr=1-5
# scraping: https://www.amazon.com/dp/product-reviews/B08FX1YJDS?pageNumber=1
# Total reviews (all pages): 77
# Total reviews (all pages): 0
# C31TRIPLEDOCKPDUS
# CADUA4KDOCKPDLUS https://www.amazon.com/WAVLINK-Docking-Station-Charging-Ethernet/dp/B083B7WG4X/ref=sr_1_11?dchild=1&keywords=docking+station+2x+hdmi+2x+displayport&qid=1621987646&s=electronics&sr=1-11
# scraping: https://www.amazon.com/dp/product-reviews/B083B7WG4X?pageNumber=1
# Total reviews (all pages): 29
# CADUA4KDOCKPDLUS https://www.amazon.com/StarTech-Universal-Laptop-Docking-Station/dp/B07MWT4RM9/ref=sr_1_2?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport+power+delivery&qid=1621988010&s=electronics&sr=1-2
# CADUA4KDOCKPDLUS
# CADUAL4KDOCKPDUS https://www.amazon.com/WAVLINK-Docking-Station-Charging-Ethernet/dp/B083B7WG4X/ref=sr_1_11?dchild=1&keywords=docking+station+2x+hdmi+2x+displayport&qid=1621987646&s=electronics&sr=1-11
# scraping: https://www.amazon.com/dp/product-reviews/B083B7WG4X?pageNumber=1
# scraping: https://www.amazon.com/dp/product-reviews/B07MWT4RM9?pageNumber=1
# CADUAL4KDOCKPDUS https://www.amazon.com/StarTech-Universal-Laptop-Docking-Station/dp/B07MWT4RM9/ref=sr_1_2?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport+power+delivery&qid=1621988010&s=electronics&sr=1-2
# scraping: https://www.amazon.com/dp/product-reviews/B07MWT4RM9?pageNumber=1
# Total reviews (all pages): 29
# Total reviews (all pages): 23
# Total reviews (all pages): 23
# CADUAL4KDOCKPDUS
# CADUAL4KDOCKUS https://www.amazon.com/Wavlink-Ethernet-DL6950-PD-Function-Supported/dp/B07DCLK55V/ref=sr_1_25?dchild=1&keywords=docking+station+2x+hdmi+2x+displayport&qid=1621987646&s=electronics&sr=1-25
# scraping: https://www.amazon.com/dp/product-reviews/B07DCLK55V?pageNumber=1
# CADUAL4KDOCKUS https://www.amazon.com/Plugable-Display-DisplayPort-Ethernet-Vertical/dp/B08B6CZ29Q/ref=sr_1_16?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport&qid=1621987828&s=electronics&sr=1-16
# scraping: https://www.amazon.com/dp/product-reviews/B08B6CZ29Q?pageNumber=1
# CADUAL4KDOCKUS
# CATRIPLE4KDOCKPDUS https://www.amazon.com/StarTech-com-USB-C-USB-Dock-DisplayPort/dp/B08J4HD9YM/ref=sr_1_6?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport&qid=1621987828&s=electronics&sr=1-6
# scraping: https://www.amazon.com/dp/product-reviews/B08J4HD9YM?pageNumber=1
# CATRIPLE4KDOCKPDUS https://www.amazon.com/Docking-Station-Notebook-Delivery-DisplayPorts/dp/B07VQTHK1M/ref=sr_1_38?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport+power+delivery&qid=1621988191&s=electronics&sr=1-38
# scraping: https://www.amazon.com/dp/product-reviews/B07VQTHK1M?pageNumber=1
# Total reviews (all pages): 169
# Total reviews (all pages): 135
# Total reviews (all pages): 23
# Total reviews (all pages): 2
# CATRIPLE4KDOCKPDUS
# TB3CDUALDPDOCKPDUS https://www.amazon.com/Plugable-Thunderbolt-Certification-Charging-Monitor/dp/B08HR3T837/ref=sr_1_4?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621988418&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B08HR3T837?pageNumber=1
# TB3CDUALDPDOCKPDUS https://www.amazon.com/Kensington-SD5200T-Thunderbolt-Docking-Station/dp/B0785DQLZ7/ref=sr_1_12?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621988418&s=electronics&sr=1-12
# scraping: https://www.amazon.com/dp/product-reviews/B0785DQLZ7?pageNumber=1
# TB3CDUALDPDOCKPDUS https://www.amazon.com/Plugable-Thunderbolt-Charging-Compatible-DisplayPort/dp/B0845X1LV7/ref=sr_1_21?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621988418&s=electronics&sr=1-21
# scraping: https://www.amazon.com/dp/product-reviews/B0845X1LV7?pageNumber=1
# Total reviews (all pages): 168
# Total reviews (all pages): 56
# TB3DUAL4KDP https://www.amazon.com/OWC-Thunderbolt-3-Dual-DisplayPort-Adapter/dp/B077T485Y1/ref=sr_1_4?dchild=1&keywords=thunderbolt+3+dual+displayport+adapter&qid=1621988783&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B077T485Y1?pageNumber=1
# Total reviews (all pages): 27
# Total reviews (all pages): 21
# TB3DUAL4KDP https://www.amazon.com/StarTech-com-Thunderbolt-DisplayPort-Adapter-Thunderbolt/dp/B072JK37LV/ref=sr_1_5?dchild=1&keywords=thunderbolt+3+dual+displayport+adapter&qid=1621988783&s=electronics&sr=1-5
# scraping: https://www.amazon.com/dp/product-reviews/B072JK37LV?pageNumber=1
# TB3DUAL4KDP https://www.amazon.com/Sabrent-Thunderbolt-DisplayPort-Supports-TH-3DP2/dp/B079JJ2MTR/ref=sr_1_6?dchild=1&keywords=thunderbolt+3+dual+displayport+adapter&qid=1621988783&s=electronics&sr=1-6
# scraping: https://www.amazon.com/dp/product-reviews/B079JJ2MTR?pageNumber=1
# Total reviews (all pages): 73
# TB3DUAL4KHDMI https://www.amazon.com/Sabrent-TH-W3H2-Thunderbolt-Supports-Monitors/dp/B07KB7NKR9/ref=sr_1_4?dchild=1&keywords=thunderbolt+3+dual+hdmi+adapter&qid=1621988671&s=electronics&sr=1-4
# TB3DUAL4KHDMI https://www.amazon.com/Plugable-Thunderbolt-Compatible-Supports-Monitors/dp/B075RTTFDJ/ref=sr_1_9?dchild=1&keywords=thunderbolt+3+dual+hdmi+adapter&qid=1621988671&s=electronics&sr=1-9
# scraping: https://www.amazon.com/dp/product-reviews/B07KB7NKR9?pageNumber=1scraping: https://www.amazon.com/dp/product-reviews/B075RTTFDJ?pageNumber=1
#
# Total reviews (all pages): 66
# Total reviews (all pages): 80
# Total reviews (all pages): 468
# TB3DUAL4KHDMI https://www.amazon.com/StarTech-com-60Hz-Thunderbolt-Display-Adapter/dp/B075CLHQY7/ref=sr_1_23?dchild=1&keywords=thunderbolt+3+dual+hdmi+adapter&qid=1621988671&s=electronics&sr=1-23
# scraping: https://www.amazon.com/dp/product-reviews/B075CLHQY7?pageNumber=1
# TB3HDMIDOCKUS https://www.amazon.com/Kensington-Thunderbolt-Docking-Station-K38625US/dp/B07VL5XLBS/ref=sr_1_18?dchild=1&keywords=thunderbolt+3+docking+station+hdmi&qid=1621988339&s=electronics&sr=1-18
# scraping: https://www.amazon.com/dp/product-reviews/B07VL5XLBS?pageNumber=1
# TB3HDMIDOCKUS https://www.amazon.com/StarTech-com-Thunderbolt-Compatible-Supports-Displays/dp/B073JDZGKK/ref=sr_1_11?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621988418&s=electronics&sr=1-11
# scraping: https://www.amazon.com/dp/product-reviews/B073JDZGKK?pageNumber=1
# TB3HDMIDOCKUS https://www.amazon.com/Kensington-SD5200T-Thunderbolt-Docking-Station/dp/B0785DQLZ7/ref=sr_1_12?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621991216&s=electronics&sr=1-12
# scraping: https://www.amazon.com/dp/product-reviews/B0785DQLZ7?pageNumber=1
# Total reviews (all pages): 73
# Total reviews (all pages): 77
# Total reviews (all pages): 80
# TB3TRAVELDOCKPD https://www.amazon.com/Belkin-Thunderbolt-Windows-Laptops-Transfer/dp/B07R5CB6HY/ref=sr_1_5?dchild=1&keywords=thunderbolt+3+travel+dock&qid=1621988863&s=electronics&sr=1-5
# scraping: https://www.amazon.com/dp/product-reviews/B07R5CB6HY?pageNumber=1
# Total reviews (all pages): 56
# Total reviews (all pages): 620
# TB3TRAVELDOCKPD https://www.amazon.com/StarTech-com-Thunderbolt-Mini-Dock-USB/dp/B08KJJG7SZ/ref=sr_1_6?dchild=1&keywords=thunderbolt%2B3%2Btravel%2Bdock&qid=1621988987&s=electronics&sr=1-6&th=1
# scraping: https://www.amazon.com/dp/product-reviews/B08KJJG7SZ?pageNumber=1
# TB3TRAVELDOCKPD https://www.amazon.com/Belkin-Thunderbolt-Transfer-Upstream-Charging/dp/B08438H4GM/ref=sr_1_4?dchild=1&keywords=thunderbolt+3+travel+dock+belkin&qid=1621989112&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B08438H4GM?pageNumber=1
# TB3TRIPLEDOCKPDUS https://www.amazon.com/HP-Thunderbolt-Dock-G2-120W/dp/B07DPKVYXR/ref=sr_1_4?dchild=1&keywords=thunderbolt+3+docking+station+HP&qid=1621989200&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B07DPKVYXR?pageNumber=1
# TB3TRIPLEDOCKPDUS https://www.amazon.com/Kensington-Thunderbolt-Docking-Station-K38625US/dp/B08H4WHQ2N/ref=sr_1_5?dchild=1&keywords=Thunderbolt%2B3%2BDocking%2BStation&qid=1620484299&sr=8-5&th=1
# scraping: https://www.amazon.com/dp/product-reviews/B08H4WHQ2N?pageNumber=1
# Total reviews (all pages): 620
# Total reviews (all pages): 4
# TB3TRIPLEDOCKPDUS https://www.amazon.com/Plugable-Thunderbolt-Charging-Compatible-DisplayPort/dp/B0845X1LV7/ref=sr_1_21?dchild=1&keywords=thunderbolt+3+dual+docking+station&qid=1621988418&s=electronics&sr=1-21
# scraping: https://www.amazon.com/dp/product-reviews/B0845X1LV7?pageNumber=1
# Total reviews (all pages): 142
# Total reviews (all pages): 80
# U3DUAL4KDP https://www.amazon.com/s?k=usb+3.0+to+dual+displayport&i=electronics&ref=nb_sb_noss_2
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# Pulling Reviews Failed
# U3DUAL4KDP
# U3DUAL4KDP
# U3DUAL4KHDMI https://www.amazon.com/USB-Dual-HDMI-Adapter-External/dp/B0725K1MHH/ref=sr_1_4?crid=S6QYG9DEMBNG&dchild=1&keywords=usb+3.0+dual+hdmi+adapter&qid=1621989429&s=electronics&sprefix=USB+3.0+dual+hdmi%2Celectronics%2C342&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B0725K1MHH?pageNumber=1
# Total reviews (all pages): 27
# Total reviews (all pages): 955
# U3DUAL4KHDMI https://www.amazon.com/UNSTINCER-Compatible-Windows7-ChromeBook-Different/dp/B08C24523X/ref=sr_1_6?crid=S6QYG9DEMBNG&dchild=1&keywords=usb+3.0+dual+hdmi+adapter&qid=1621989429&s=electronics&sprefix=USB+3.0+dual+hdmi%2Celectronics%2C342&sr=1-6
# scraping: https://www.amazon.com/dp/product-reviews/B08C24523X?pageNumber=1
# U3DUAL4KHDMI
# U3DUALHDMIDOCKUS https://www.amazon.com/Universal-Laptop-Docking-Station-Windows/dp/B081S5XL28/ref=sr_1_7?dchild=1&keywords=usb+3.0+dual+hdmi+dock&qid=1621989954&s=electronics&sr=1-7
# scraping: https://www.amazon.com/dp/product-reviews/B081S5XL28?pageNumber=1
# Total reviews (all pages): 112
# Total reviews (all pages): 45
# U3DUALHDMIDOCKUS
# U3DUALHDMIDOCKUS
# U3HDMIDVIDOCKUS https://www.amazon.com/Wavlink-Universal-Docking-Ethernet-Ultrabook/dp/B019XOJ874/ref=sr_1_29?dchild=1&keywords=universal+docking+station+2x+hdmi+2x+displayport+power+delivery&qid=1621988191&s=electronics&sr=1-29
# scraping: https://www.amazon.com/dp/product-reviews/B019XOJ874?pageNumber=1
# U3HDMIDVIDOCKUS https://www.amazon.com/Plugable-Universal-Docking-Station-Ethernet/dp/B00ECDM78E/ref=sr_1_4?dchild=1&keywords=usb+3.0+hdmi+dvi+dock&qid=1621989848&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B00ECDM78E?pageNumber=1
# Total reviews (all pages): 365
# Total reviews (all pages): 3737
# U3HDMIDVIDOCKUS https://www.amazon.com/Universal-Docking-Acodot-Equipped-Ethernet/dp/B0832K7NS9/ref=sr_1_16?dchild=1&keywords=usb+3.0+hdmi+dvi+dock&qid=1621989848&s=electronics&sr=1-16
# scraping: https://www.amazon.com/dp/product-reviews/B0832K7NS9?pageNumber=1
# Total reviews (all pages): 405
# VESADOCK1 https://www.amazon.com/Kensington-Docking-VESA-Compatible-Mounting-K33959WW/dp/B01ABSLMHK/ref=sr_1_4?dchild=1&keywords=vesa+bracket+dock&qid=1621990026&s=electronics&sr=1-4
# scraping: https://www.amazon.com/dp/product-reviews/B01ABSLMHK?pageNumber=1
# Total reviews (all pages): 12
# VESADOCK1
# VESADOCK1
# name 'selenium' is not defined
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# Pulling Reviews Failed
# name 'selenium' is not defined
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# Pulling Reviews Failed

# %%
# review_master_dict = {}
# for PN, urls in url_dict.items():
#     review_master_dict[PN] = {}
#     for i, url in enumerate(urls):
#         if url:
#             try:
#                 review_master_dict[PN][url] = scraper.scrape('amazon.com', url=url)
#             except Exception as e:
#                 print(e)

# %%
import json

with open("reviews.json", 'w') as f:
    json.dump(review_master_dict, f)

# %%
# df.drop([0, df.index[-1]], inplace=True)

# %%
review_master_dict
